# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import citipy module
from citipy import citipy

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import the API key.
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url+"&q=victoria"

# %%
response = requests.get(city_url).json()
response
# Out:
# {'coord': {'lon': 114.1577, 'lat': 22.2855},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 64.2,
#   'feels_like': 63.79,
#   'temp_min': 62.01,
#   'temp_max': 66.99,
#   'pressure': 1016,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 3.91, 'deg': 101},
#  'clouds': {'all': 0},
#  'dt': 1612633386,
#  'sys': {'type': 3,
#   'id': 2035800,
#   'country': 'HK',
#   'sunrise': 1612652376,
#   'sunset': 1612692927},
#  'timezone': 28800,
#  'id': 1819729,
#  'name': 'Hong Kong',
#  'cod': 200}

# %%
response["weather"][0]["description"]
# Out:
# 'clear sky'

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chauk
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | leningradskiy
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | roma
# Processing Record 6 of Set 1 | boralday
# Processing Record 7 of Set 1 | tuatapere
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | progreso
# Processing Record 12 of Set 1 | kaeo
# Processing Record 13 of Set 1 | havoysund
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | ilam
# Processing Record 18 of Set 1 | ulaanbaatar
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | pontianak
# Processing Record 22 of Set 1 | namatanai
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | aklavik
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | kulunda
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | pangkalanbuun
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | alexandria
# Processing Record 44 of Set 1 | padang
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | majene
# Processing Record 48 of Set 1 | general pico
# Processing Record 49 of Set 1 | port macquarie
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | kresek
# Processing Record 3 of Set 2 | buala
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | alofi
# Processing Record 7 of Set 2 | sioux lookout
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | yarim
# Processing Record 10 of Set 2 | penzance
# Processing Record 11 of Set 2 | antofagasta
# Processing Record 12 of Set 2 | salalah
# Processing Record 13 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 2 | nishihara
# Processing Record 15 of Set 2 | charters towers
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | tomatlan
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | marsh harbour
# Processing Record 21 of Set 2 | tabat
# Processing Record 22 of Set 2 | piranhas
# Processing Record 23 of Set 2 | la primavera
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | altoona
# Processing Record 27 of Set 2 | uige
# Processing Record 28 of Set 2 | ugoofaaru
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | ornskoldsvik
# Processing Record 35 of Set 2 | marbella
# Processing Record 36 of Set 2 | hamilton
# Processing Record 37 of Set 2 | ampanihy
# Processing Record 38 of Set 2 | burica
# City not found. Skipping...
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | nelson
# Processing Record 41 of Set 2 | naze
# Processing Record 42 of Set 2 | tungor
# Processing Record 43 of Set 2 | beringovskiy
# Processing Record 44 of Set 2 | meulaboh
# Processing Record 45 of Set 2 | bjornevatn
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | raudeberg
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | palmeiras de goias
# Processing Record 1 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | obama
# Processing Record 3 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | kununurra
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 3 | porto nacional
# Processing Record 12 of Set 3 | nyurba
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | la rioja
# Processing Record 15 of Set 3 | copala
# Processing Record 16 of Set 3 | sao joao da barra
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | aquiraz
# Processing Record 19 of Set 3 | qaqortoq
# Processing Record 20 of Set 3 | jagdalpur
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | mandalgovi
# Processing Record 25 of Set 3 | yenotayevka
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | korla
# Processing Record 30 of Set 3 | sisimiut
# Processing Record 31 of Set 3 | lentekhi
# Processing Record 32 of Set 3 | samfya
# Processing Record 33 of Set 3 | esso
# Processing Record 34 of Set 3 | bouna
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | ranong
# Processing Record 38 of Set 3 | rawson
# Processing Record 39 of Set 3 | mabaruma
# Processing Record 40 of Set 3 | saint-pierre
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | narasannapeta
# Processing Record 45 of Set 3 | xai-xai
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | gat
# Processing Record 50 of Set 3 | empalme
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | sembe
# Processing Record 4 of Set 4 | vestmannaeyjar
# Processing Record 5 of Set 4 | mbini
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | iquique
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | champerico
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | ambilobe
# Processing Record 12 of Set 4 | sakakah
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | port blair
# Processing Record 15 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | marzuq
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | yarmouth
# Processing Record 20 of Set 4 | nieuw amsterdam
# Processing Record 21 of Set 4 | amnat charoen
# Processing Record 22 of Set 4 | ancud
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | barreiras
# Processing Record 25 of Set 4 | sambava
# Processing Record 26 of Set 4 | nanganga
# Processing Record 27 of Set 4 | north bend
# Processing Record 28 of Set 4 | myaundzha
# Processing Record 29 of Set 4 | barrow
# Processing Record 30 of Set 4 | belaya kholunitsa
# Processing Record 31 of Set 4 | garden city
# Processing Record 32 of Set 4 | carupano
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | ust-maya
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | ust-nera
# Processing Record 37 of Set 4 | namibe
# Processing Record 38 of Set 4 | soto
# Processing Record 39 of Set 4 | eyl
# Processing Record 40 of Set 4 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | harpenden
# Processing Record 43 of Set 4 | ekhabi
# Processing Record 44 of Set 4 | araouane
# Processing Record 45 of Set 4 | bismarck
# Processing Record 46 of Set 4 | sinor
# Processing Record 47 of Set 4 | chifeng
# Processing Record 48 of Set 4 | kahului
# Processing Record 49 of Set 4 | bandarbeyla
# Processing Record 50 of Set 4 | puerto del rosario
# Processing Record 1 of Set 5 | soyo
# Processing Record 2 of Set 5 | praya
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | lebyazhye
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | rudnya
# Processing Record 9 of Set 5 | buzescu
# Processing Record 10 of Set 5 | opunake
# Processing Record 11 of Set 5 | marawi
# Processing Record 12 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 5 | pandan
# Processing Record 14 of Set 5 | adre
# Processing Record 15 of Set 5 | katsuura
# Processing Record 16 of Set 5 | tena
# Processing Record 17 of Set 5 | kapaa
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | buwenge
# Processing Record 20 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 5 | gizo
# Processing Record 22 of Set 5 | poddorye
# Processing Record 23 of Set 5 | zhigansk
# Processing Record 24 of Set 5 | dutse
# Processing Record 25 of Set 5 | wa
# City not found. Skipping...
# Processing Record 26 of Set 5 | oriximina
# Processing Record 27 of Set 5 | chuy
# Processing Record 28 of Set 5 | tukrah
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 5 | nouadhibou
# Processing Record 31 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 5 | ghatampur
# Processing Record 33 of Set 5 | te anau
# Processing Record 34 of Set 5 | georgetown
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | kenai
# Processing Record 37 of Set 5 | atambua
# Processing Record 38 of Set 5 | japura
# Processing Record 39 of Set 5 | tripoli
# Processing Record 40 of Set 5 | seymchan
# Processing Record 41 of Set 5 | quang ngai
# Processing Record 42 of Set 5 | birjand
# Processing Record 43 of Set 5 | diego de almagro
# Processing Record 44 of Set 5 | saravan
# Processing Record 45 of Set 5 | zyryanka
# Processing Record 46 of Set 5 | yanliang
# Processing Record 47 of Set 5 | yavatmal
# Processing Record 48 of Set 5 | benghazi
# Processing Record 49 of Set 5 | vao
# Processing Record 50 of Set 5 | linhares
# Processing Record 1 of Set 6 | kavieng
# Processing Record 2 of Set 6 | stuttgart
# Processing Record 3 of Set 6 | haines junction
# Processing Record 4 of Set 6 | zaysan
# Processing Record 5 of Set 6 | atar
# Processing Record 6 of Set 6 | long beach
# Processing Record 7 of Set 6 | smolenka
# Processing Record 8 of Set 6 | egvekinot
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | virtsu
# Processing Record 11 of Set 6 | rio branco
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | port hedland
# Processing Record 14 of Set 6 | sinjar
# Processing Record 15 of Set 6 | nhulunbuy
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | bad freienwalde
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | shache
# Processing Record 20 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 6 | severo-kurilsk
# Processing Record 22 of Set 6 | qiyang
# Processing Record 23 of Set 6 | sitka
# Processing Record 24 of Set 6 | betare oya
# Processing Record 25 of Set 6 | karistos
# City not found. Skipping...
# Processing Record 26 of Set 6 | balkhash
# Processing Record 27 of Set 6 | lodja
# Processing Record 28 of Set 6 | le port
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | tezu
# Processing Record 31 of Set 6 | sterling
# Processing Record 32 of Set 6 | sola
# Processing Record 33 of Set 6 | polyany
# Processing Record 34 of Set 6 | svetlaya
# Processing Record 35 of Set 6 | mana
# Processing Record 36 of Set 6 | constitucion
# Processing Record 37 of Set 6 | upernavik
# Processing Record 38 of Set 6 | locri
# Processing Record 39 of Set 6 | pisco
# Processing Record 40 of Set 6 | rio grande
# Processing Record 41 of Set 6 | anuradhapura
# Processing Record 42 of Set 6 | corrente
# Processing Record 43 of Set 6 | hami
# Processing Record 44 of Set 6 | tabas
# Processing Record 45 of Set 6 | ponta do sol
# Processing Record 46 of Set 6 | bilibino
# Processing Record 47 of Set 6 | bathsheba
# Processing Record 48 of Set 6 | gari
# Processing Record 49 of Set 6 | batagay-alyta
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | broome
# Processing Record 2 of Set 7 | vila franca do campo
# Processing Record 3 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 7 | ostrovnoy
# Processing Record 5 of Set 7 | kjollefjord
# Processing Record 6 of Set 7 | verkhnetulomskiy
# Processing Record 7 of Set 7 | zhangye
# Processing Record 8 of Set 7 | den helder
# Processing Record 9 of Set 7 | vanavara
# Processing Record 10 of Set 7 | bardiyah
# Processing Record 11 of Set 7 | abong mbang
# Processing Record 12 of Set 7 | naryan-mar
# Processing Record 13 of Set 7 | riosucio
# Processing Record 14 of Set 7 | esperance
# Processing Record 15 of Set 7 | bowen
# Processing Record 16 of Set 7 | kiunga
# Processing Record 17 of Set 7 | kloulklubed
# Processing Record 18 of Set 7 | koch bihar
# Processing Record 19 of Set 7 | hearst
# Processing Record 20 of Set 7 | baykit
# Processing Record 21 of Set 7 | monchegorsk
# Processing Record 22 of Set 7 | sangar
# Processing Record 23 of Set 7 | trelew
# Processing Record 24 of Set 7 | berdigestyakh
# Processing Record 25 of Set 7 | sorland
# Processing Record 26 of Set 7 | sarahan
# Processing Record 27 of Set 7 | clinton
# Processing Record 28 of Set 7 | new smyrna beach
# Processing Record 29 of Set 7 | axim
# Processing Record 30 of Set 7 | cherskiy
# Processing Record 31 of Set 7 | oktyabrskoye
# Processing Record 32 of Set 7 | chamonix-mont-blanc
# Processing Record 33 of Set 7 | mayo
# Processing Record 34 of Set 7 | galle
# Processing Record 35 of Set 7 | bria
# Processing Record 36 of Set 7 | skowhegan
# Processing Record 37 of Set 7 | iralaya
# Processing Record 38 of Set 7 | aykhal
# Processing Record 39 of Set 7 | nizwa
# Processing Record 40 of Set 7 | kulhudhuffushi
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | dinard
# Processing Record 43 of Set 7 | resistencia
# Processing Record 44 of Set 7 | alegre
# Processing Record 45 of Set 7 | rancho palos verdes
# Processing Record 46 of Set 7 | inongo
# Processing Record 47 of Set 7 | sur
# Processing Record 48 of Set 7 | santa cruz
# Processing Record 49 of Set 7 | ewa beach
# Processing Record 50 of Set 7 | lichtenburg
# Processing Record 1 of Set 8 | mount pleasant
# Processing Record 2 of Set 8 | katav-ivanovsk
# Processing Record 3 of Set 8 | moose factory
# Processing Record 4 of Set 8 | lensk
# Processing Record 5 of Set 8 | paamiut
# Processing Record 6 of Set 8 | magaria
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | alice springs
# Processing Record 9 of Set 8 | san-pedro
# Processing Record 10 of Set 8 | sergeyevka
# Processing Record 11 of Set 8 | terrace
# Processing Record 12 of Set 8 | walvis bay
# Processing Record 13 of Set 8 | jinchang
# Processing Record 14 of Set 8 | honningsvag
# Processing Record 15 of Set 8 | limay
# Processing Record 16 of Set 8 | kalabo
# Processing Record 17 of Set 8 | high level
# Processing Record 18 of Set 8 | ucluelet
# Processing Record 19 of Set 8 | bourail
# Processing Record 20 of Set 8 | avera
# Processing Record 21 of Set 8 | ambon
# Processing Record 22 of Set 8 | manono
# Processing Record 23 of Set 8 | mehamn
# Processing Record 24 of Set 8 | sibu
# Processing Record 25 of Set 8 | anloga
# Processing Record 26 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 27 of Set 8 | berlevag
# Processing Record 28 of Set 8 | sterlibashevo
# Processing Record 29 of Set 8 | palm coast
# Processing Record 30 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 8 | juneau
# Processing Record 33 of Set 8 | nanortalik
# Processing Record 34 of Set 8 | shimanovsk
# Processing Record 35 of Set 8 | batticaloa
# Processing Record 36 of Set 8 | saurimo
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | ondangwa
# Processing Record 41 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 8 | lishan
# Processing Record 43 of Set 8 | mandal
# Processing Record 44 of Set 8 | dingzhou
# Processing Record 45 of Set 8 | saldanha
# Processing Record 46 of Set 8 | kuantan
# Processing Record 47 of Set 8 | saint-augustin
# Processing Record 48 of Set 8 | hagere selam
# Processing Record 49 of Set 8 | funadhoo
# Processing Record 50 of Set 8 | guerrero negro
# Processing Record 1 of Set 9 | bien hoa
# Processing Record 2 of Set 9 | campina verde
# Processing Record 3 of Set 9 | puerto asis
# Processing Record 4 of Set 9 | port hardy
# Processing Record 5 of Set 9 | irbeyskoye
# Processing Record 6 of Set 9 | karatsu
# Processing Record 7 of Set 9 | abalak
# Processing Record 8 of Set 9 | severobaykalsk
# Processing Record 9 of Set 9 | deputatskiy
# Processing Record 10 of Set 9 | makushino
# Processing Record 11 of Set 9 | boulder
# Processing Record 12 of Set 9 | sabang
# Processing Record 13 of Set 9 | dicabisagan
# Processing Record 14 of Set 9 | goroka
# Processing Record 15 of Set 9 | solana beach
# Processing Record 16 of Set 9 | necochea
# Processing Record 17 of Set 9 | flinders
# Processing Record 18 of Set 9 | huaihua
# Processing Record 19 of Set 9 | kutum
# Processing Record 20 of Set 9 | homer
# Processing Record 21 of Set 9 | okha
# Processing Record 22 of Set 9 | bata
# Processing Record 23 of Set 9 | katherine
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | saint-georges
# Processing Record 26 of Set 9 | prince rupert
# Processing Record 27 of Set 9 | hervey bay
# Processing Record 28 of Set 9 | olavarria
# Processing Record 29 of Set 9 | henties bay
# Processing Record 30 of Set 9 | dunedin
# Processing Record 31 of Set 9 | sao filipe
# Processing Record 32 of Set 9 | chipinge
# Processing Record 33 of Set 9 | yeppoon
# Processing Record 34 of Set 9 | severo-yeniseyskiy
# Processing Record 35 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 9 | gemena
# Processing Record 37 of Set 9 | ormara
# Processing Record 38 of Set 9 | richards bay
# Processing Record 39 of Set 9 | atherton
# Processing Record 40 of Set 9 | santa rosalia
# Processing Record 41 of Set 9 | kedrovyy
# Processing Record 42 of Set 9 | qingan
# City not found. Skipping...
# Processing Record 43 of Set 9 | strezhevoy
# Processing Record 44 of Set 9 | dafeng
# Processing Record 45 of Set 9 | laguna
# Processing Record 46 of Set 9 | bilma
# Processing Record 47 of Set 9 | verkh-usugli
# Processing Record 48 of Set 9 | bangsund
# Processing Record 49 of Set 9 | saint-fabien
# City not found. Skipping...
# Processing Record 50 of Set 9 | tiksi
# Processing Record 1 of Set 10 | khatanga
# Processing Record 2 of Set 10 | mporokoso
# Processing Record 3 of Set 10 | sechura
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | pochutla
# Processing Record 6 of Set 10 | yenagoa
# Processing Record 7 of Set 10 | riyadh
# Processing Record 8 of Set 10 | portland
# Processing Record 9 of Set 10 | dongli
# Processing Record 10 of Set 10 | loa janan
# Processing Record 11 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | gisborne
# Processing Record 14 of Set 10 | muna
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | malanville
# Processing Record 17 of Set 10 | dosso
# Processing Record 18 of Set 10 | vostok
# Processing Record 19 of Set 10 | ploemeur
# Processing Record 20 of Set 10 | grindavik
# Processing Record 21 of Set 10 | ojinaga
# Processing Record 22 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 23 of Set 10 | los chiles
# Processing Record 24 of Set 10 | novoagansk
# Processing Record 25 of Set 10 | duldurga
# Processing Record 26 of Set 10 | angoche
# Processing Record 27 of Set 10 | coruripe
# Processing Record 28 of Set 10 | vallenar
# Processing Record 29 of Set 10 | tongzi
# Processing Record 30 of Set 10 | gainesville
# Processing Record 31 of Set 10 | codajas
# Processing Record 32 of Set 10 | saint-francois
# Processing Record 33 of Set 10 | quchan
# Processing Record 34 of Set 10 | umea
# Processing Record 35 of Set 10 | bonavista
# Processing Record 36 of Set 10 | filingue
# Processing Record 37 of Set 10 | wajir
# Processing Record 38 of Set 10 | mnogovershinnyy
# Processing Record 39 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 40 of Set 10 | goure
# Processing Record 41 of Set 10 | iqaluit
# Processing Record 42 of Set 10 | halifax
# Processing Record 43 of Set 10 | iwaki
# Processing Record 44 of Set 10 | xining
# Processing Record 45 of Set 10 | warrington
# Processing Record 46 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 47 of Set 10 | moron
# Processing Record 48 of Set 10 | bulgan
# Processing Record 49 of Set 10 | port shepstone
# Processing Record 50 of Set 10 | farafangana
# Processing Record 1 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 11 | yangambi
# Processing Record 4 of Set 11 | havelock
# Processing Record 5 of Set 11 | labuhan
# Processing Record 6 of Set 11 | dodola
# Processing Record 7 of Set 11 | yasnyy
# Processing Record 8 of Set 11 | roald
# Processing Record 9 of Set 11 | tartagal
# Processing Record 10 of Set 11 | flin flon
# Processing Record 11 of Set 11 | chaihe
# Processing Record 12 of Set 11 | skibbereen
# Processing Record 13 of Set 11 | kalmunai
# Processing Record 14 of Set 11 | deniliquin
# Processing Record 15 of Set 11 | vanimo
# Processing Record 16 of Set 11 | xiuyan
# Processing Record 17 of Set 11 | houma
# Processing Record 18 of Set 11 | barra velha
# Processing Record 19 of Set 11 | manjacaze
# Processing Record 20 of Set 11 | santa rosa
# Processing Record 21 of Set 11 | paka
# Processing Record 22 of Set 11 | huarmey
# Processing Record 23 of Set 11 | mirnyy
# Processing Record 24 of Set 11 | villars-sur-glane
# Processing Record 25 of Set 11 | kupang
# Processing Record 26 of Set 11 | coffeyville
# Processing Record 27 of Set 11 | tandil
# Processing Record 28 of Set 11 | zvishavane
# Processing Record 29 of Set 11 | athens
# Processing Record 30 of Set 11 | freeport
# Processing Record 31 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 11 | xuddur
# Processing Record 33 of Set 11 | wucheng
# Processing Record 34 of Set 11 | juan lacaze
# Processing Record 35 of Set 11 | beira
# Processing Record 36 of Set 11 | povenets
# Processing Record 37 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 11 | ushtobe
# Processing Record 39 of Set 11 | les cayes
# Processing Record 40 of Set 11 | marsa matruh
# Processing Record 41 of Set 11 | cordoba
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 11 | plettenberg bay
# Processing Record 45 of Set 11 | wolfsberg
# Processing Record 46 of Set 11 | toamasina
# Processing Record 47 of Set 11 | norrtalje
# Processing Record 48 of Set 11 | chippewa falls
# Processing Record 49 of Set 11 | gornopravdinsk
# Processing Record 50 of Set 11 | akureyri
# Processing Record 1 of Set 12 | fairlie
# Processing Record 2 of Set 12 | ayorou
# Processing Record 3 of Set 12 | safford
# Processing Record 4 of Set 12 | samarai
# Processing Record 5 of Set 12 | podgorica
# Processing Record 6 of Set 12 | fagersta
# Processing Record 7 of Set 12 | hobyo
# Processing Record 8 of Set 12 | pontiac
# Processing Record 9 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 10 of Set 12 | sawtell
# Processing Record 11 of Set 12 | iskateley
# Processing Record 12 of Set 12 | alto araguaia
# Processing Record 13 of Set 12 | guangyuan
# Processing Record 14 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 15 of Set 12 | acari
# Processing Record 16 of Set 12 | rocha
# Processing Record 17 of Set 12 | kasempa
# Processing Record 18 of Set 12 | sakaiminato
# Processing Record 19 of Set 12 | mering
# Processing Record 20 of Set 12 | oistins
# Processing Record 21 of Set 12 | praia da vitoria
# Processing Record 22 of Set 12 | kayes
# Processing Record 23 of Set 12 | sosva
# Processing Record 24 of Set 12 | lovozero
# Processing Record 25 of Set 12 | bull savanna
# Processing Record 26 of Set 12 | bontang
# Processing Record 27 of Set 12 | yumen
# Processing Record 28 of Set 12 | acarau
# Processing Record 29 of Set 12 | caravelas
# Processing Record 30 of Set 12 | sobolevo
# Processing Record 31 of Set 12 | lethem
# Processing Record 32 of Set 12 | udachnyy
# Processing Record 33 of Set 12 | otane
# Processing Record 34 of Set 12 | kapit
# Processing Record 35 of Set 12 | ossora
# Processing Record 36 of Set 12 | nome
# Processing Record 37 of Set 12 | mackay
# Processing Record 38 of Set 12 | miri
# Processing Record 39 of Set 12 | paracuru
# Processing Record 40 of Set 12 | san pedro
# Processing Record 41 of Set 12 | tessalit
# Processing Record 42 of Set 12 | puerto escondido
# Processing Record 43 of Set 12 | pringsewu
# Processing Record 44 of Set 12 | lakselv
# Processing Record 45 of Set 12 | antalaha
# Processing Record 46 of Set 12 | gavrilov-yam
# Processing Record 47 of Set 12 | port keats
# Processing Record 48 of Set 12 | corsicana
# Processing Record 49 of Set 12 | adrar
# Processing Record 50 of Set 12 | gravdal
# Processing Record 1 of Set 13 | la ronge
# Processing Record 2 of Set 13 | kungurtug
# Processing Record 3 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 13 | rio de jesus
# Processing Record 5 of Set 13 | parkes
# Processing Record 6 of Set 13 | bubaque
# Processing Record 7 of Set 13 | isiolo
# Processing Record 8 of Set 13 | bukid
# Processing Record 9 of Set 13 | half moon bay
# Processing Record 10 of Set 13 | antigonish
# Processing Record 11 of Set 13 | goundi
# Processing Record 12 of Set 13 | kailua
# Processing Record 13 of Set 13 | teguldet
# Processing Record 14 of Set 13 | wagrowiec
# Processing Record 15 of Set 13 | jumla
# Processing Record 16 of Set 13 | constantine
# Processing Record 17 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 13 | atbasar
# Processing Record 19 of Set 13 | kidal
# Processing Record 20 of Set 13 | rabo de peixe
# Processing Record 21 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 13 | redmond
# Processing Record 23 of Set 13 | pimentel
# Processing Record 24 of Set 13 | moramanga
# Processing Record 25 of Set 13 | lagoa
# Processing Record 26 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 13 | vila velha
# Processing Record 28 of Set 13 | port-gentil
# Processing Record 29 of Set 13 | evensk
# Processing Record 30 of Set 13 | khandbari
# Processing Record 31 of Set 13 | sibolga
# Processing Record 32 of Set 13 | landskrona
# Processing Record 33 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 13 | kirando
# Processing Record 35 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 36 of Set 13 | viking
# Processing Record 37 of Set 13 | orel-izumrud
# Processing Record 38 of Set 13 | nalut
# Processing Record 39 of Set 13 | ende
# Processing Record 40 of Set 13 | kansanshi
# Processing Record 41 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 13 | santiago
# Processing Record 43 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 13 | morristown
# Processing Record 45 of Set 13 | preobrazheniye
# Processing Record 46 of Set 13 | cooma
# Processing Record 47 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 13 | vokhtoga
# Processing Record 50 of Set 13 | rock sound
# Processing Record 1 of Set 14 | lima
# Processing Record 2 of Set 14 | rio gallegos
# Processing Record 3 of Set 14 | kibala
# Processing Record 4 of Set 14 | dongsheng
# Processing Record 5 of Set 14 | iquitos
# Processing Record 6 of Set 14 | fare
# Processing Record 7 of Set 14 | kamenka
# Processing Record 8 of Set 14 | tura
# Processing Record 9 of Set 14 | illapel
# Processing Record 10 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 14 | vila
# Processing Record 12 of Set 14 | karanja
# Processing Record 13 of Set 14 | ulladulla
# Processing Record 14 of Set 14 | staryy nadym
# Processing Record 15 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 14 | vengerovo
# Processing Record 17 of Set 14 | tomohon
# Processing Record 18 of Set 14 | pauini
# Processing Record 19 of Set 14 | bairiki
# Processing Record 20 of Set 14 | larsnes
# Processing Record 21 of Set 14 | jijiga
# Processing Record 22 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 23 of Set 14 | tahoua
# Processing Record 24 of Set 14 | sarkand
# Processing Record 25 of Set 14 | cockburn town
# Processing Record 26 of Set 14 | skole
# Processing Record 27 of Set 14 | bonthe
# Processing Record 28 of Set 14 | wajima
# Processing Record 29 of Set 14 | areia branca
# Processing Record 30 of Set 14 | koutsouras
# Processing Record 31 of Set 14 | makakilo city
# Processing Record 32 of Set 14 | yulara
# Processing Record 33 of Set 14 | doha
# Processing Record 34 of Set 14 | alyangula
# Processing Record 35 of Set 14 | shahr-e babak
# Processing Record 36 of Set 14 | hovd
# Processing Record 37 of Set 14 | jalu
# Processing Record 38 of Set 14 | eureka
# Processing Record 39 of Set 14 | kenora
# Processing Record 40 of Set 14 | batagay
# Processing Record 41 of Set 14 | chumikan
# Processing Record 42 of Set 14 | serov
# Processing Record 43 of Set 14 | palana
# Processing Record 44 of Set 14 | szentlorinc
# Processing Record 45 of Set 14 | huanta
# Processing Record 46 of Set 14 | tazovskiy
# Processing Record 47 of Set 14 | carballo
# Processing Record 48 of Set 14 | kuala terengganu
# Processing Record 49 of Set 14 | rongcheng
# Processing Record 50 of Set 14 | lerwick
# Processing Record 1 of Set 15 | zabol
# Processing Record 2 of Set 15 | hebertville
# City not found. Skipping...
# Processing Record 3 of Set 15 | misratah
# Processing Record 4 of Set 15 | christiana
# Processing Record 5 of Set 15 | sento se
# City not found. Skipping...
# Processing Record 6 of Set 15 | maldonado
# Processing Record 7 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 15 | alegrete
# Processing Record 9 of Set 15 | abangay
# Processing Record 10 of Set 15 | salta
# Processing Record 11 of Set 15 | kurtamysh
# Processing Record 12 of Set 15 | iracoubo
# Processing Record 13 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 15 | ahipara
# Processing Record 15 of Set 15 | umbertide
# Processing Record 16 of Set 15 | bima
# Processing Record 17 of Set 15 | great falls
# Processing Record 18 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 15 | umm lajj
# Processing Record 20 of Set 15 | ginir
# Processing Record 21 of Set 15 | vredendal
# Processing Record 22 of Set 15 | kalaleh
# Processing Record 23 of Set 15 | raduzhnyy
# Processing Record 24 of Set 15 | okmulgee
# Processing Record 25 of Set 15 | tromso
# Processing Record 26 of Set 15 | shelburne
# Processing Record 27 of Set 15 | saryozek
# Processing Record 28 of Set 15 | black river
# Processing Record 29 of Set 15 | yamada
# Processing Record 30 of Set 15 | zapolyarnyy
# Processing Record 31 of Set 15 | hualmay
# Processing Record 32 of Set 15 | keffi
# Processing Record 33 of Set 15 | saint-andre-avellin
# Processing Record 34 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 15 | rayagada
# Processing Record 36 of Set 15 | milkovo
# Processing Record 37 of Set 15 | maun
# Processing Record 38 of Set 15 | luang prabang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Chauk  20.8833   94.8167     70.20        51          72
# 1     Port Lincoln -34.7333  135.8667     60.06        82          66
# 2    Leningradskiy  69.3833  178.4167    -12.82        78          61
# 3     Punta Arenas -53.1500  -70.9167     55.40        47          20
# 4             Roma  43.2128  -75.4557     28.40        50          90
# 5         Boralday  43.3578   76.8594     33.80        80          75
# 6        Tuatapere -46.1333  167.6833     51.51        85           1
# 7      Yellowknife  62.4560 -114.3525    -43.01        66           1
# 8          Rikitea -23.1203 -134.9692     77.65        74         100
# 9  Bambous Virieux -20.3428   57.7575     80.01        83          20
#
#    Wind Speed Country                 Date Weather Description
# 0        3.00      MM  2021-02-06 17:49:06       broken clouds
# 1       13.56      AU  2021-02-06 17:49:07       broken clouds
# 2        6.58      RU  2021-02-06 17:46:19       broken clouds
# 3        6.91      CL  2021-02-06 17:48:16          few clouds
# 4       20.71      US  2021-02-06 17:49:07     overcast clouds
# 5        4.47      KZ  2021-02-06 17:49:08               smoke
# 6        3.78      NZ  2021-02-06 17:49:08           clear sky
# 7        3.44      CA  2021-02-06 17:47:44                mist
# 8       12.37      PF  2021-02-06 17:49:08     overcast clouds
# 9        5.75      MU  2021-02-06 17:49:08          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
