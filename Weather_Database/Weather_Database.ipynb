# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import citipy module
from citipy import citipy

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import the API key.
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | sinnamary
# Processing Record 3 of Set 1 | qaqortoq
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | chahal
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | antalaha
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | namatanai
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | betlitsa
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | shimoda
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | banda aceh
# Processing Record 27 of Set 1 | maniitsoq
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | sabha
# Processing Record 30 of Set 1 | deputatskiy
# Processing Record 31 of Set 1 | klaksvik
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | bolshoy lug
# Processing Record 38 of Set 1 | naze
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | miri
# Processing Record 43 of Set 1 | mareeba
# Processing Record 44 of Set 1 | carutapera
# Processing Record 45 of Set 1 | portland
# Processing Record 46 of Set 1 | labrea
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 1 | tessalit
# Processing Record 1 of Set 2 | freeport
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | avera
# Processing Record 5 of Set 2 | saryg-sep
# Processing Record 6 of Set 2 | grand gaube
# Processing Record 7 of Set 2 | dire
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | sisimiut
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | luba
# Processing Record 14 of Set 2 | guderup
# Processing Record 15 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 2 | dabat
# Processing Record 17 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 2 | naryan-mar
# Processing Record 19 of Set 2 | ryotsu
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | balclutha
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | praia da vitoria
# Processing Record 25 of Set 2 | madras
# Processing Record 26 of Set 2 | madhipura
# Processing Record 27 of Set 2 | college
# Processing Record 28 of Set 2 | sterling
# Processing Record 29 of Set 2 | khandyga
# Processing Record 30 of Set 2 | kemijarvi
# Processing Record 31 of Set 2 | dunedin
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | surab
# Processing Record 34 of Set 2 | coruripe
# Processing Record 35 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 2 | coihaique
# Processing Record 38 of Set 2 | bartica
# Processing Record 39 of Set 2 | kuching
# Processing Record 40 of Set 2 | broken hill
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | lavrentiya
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | rovinj
# Processing Record 46 of Set 2 | cockburn town
# Processing Record 47 of Set 2 | sorland
# Processing Record 48 of Set 2 | coahuayana
# Processing Record 49 of Set 2 | mocuba
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | zanjan
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | cauquenes
# Processing Record 6 of Set 3 | edson
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | burnie
# Processing Record 10 of Set 3 | synya
# Processing Record 11 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | hami
# Processing Record 14 of Set 3 | nyuksenitsa
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | nelson bay
# Processing Record 17 of Set 3 | byron bay
# Processing Record 18 of Set 3 | irbeyskoye
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | segezha
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | mayumba
# Processing Record 25 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 26 of Set 3 | gobabis
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | kloulklubed
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | ambilobe
# Processing Record 32 of Set 3 | zhigansk
# Processing Record 33 of Set 3 | te anau
# Processing Record 34 of Set 3 | jumla
# Processing Record 35 of Set 3 | belmonte
# Processing Record 36 of Set 3 | moron
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | obidos
# Processing Record 39 of Set 3 | camacha
# Processing Record 40 of Set 3 | yellowknife
# Processing Record 41 of Set 3 | cuamba
# Processing Record 42 of Set 3 | wiang sa
# Processing Record 43 of Set 3 | denpasar
# Processing Record 44 of Set 3 | puerto leguizamo
# Processing Record 45 of Set 3 | mount pleasant
# Processing Record 46 of Set 3 | kapaa
# Processing Record 47 of Set 3 | atuona
# Processing Record 48 of Set 3 | bubaque
# Processing Record 49 of Set 3 | okha
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | zambezi
# Processing Record 2 of Set 4 | waipawa
# Processing Record 3 of Set 4 | los llanos de aridane
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | faya
# Processing Record 9 of Set 4 | verkhnyaya inta
# Processing Record 10 of Set 4 | juneau
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | atasu
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | saleilua
# City not found. Skipping...
# Processing Record 16 of Set 4 | moussoro
# Processing Record 17 of Set 4 | yushan
# Processing Record 18 of Set 4 | high level
# Processing Record 19 of Set 4 | kavaratti
# Processing Record 20 of Set 4 | marsh harbour
# Processing Record 21 of Set 4 | senanga
# Processing Record 22 of Set 4 | takoradi
# Processing Record 23 of Set 4 | amapa
# Processing Record 24 of Set 4 | tahara
# Processing Record 25 of Set 4 | royan
# Processing Record 26 of Set 4 | kupang
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | poya
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | kudahuvadhoo
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | biltine
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | boa vista
# Processing Record 37 of Set 4 | north bend
# Processing Record 38 of Set 4 | marzuq
# Processing Record 39 of Set 4 | kieta
# Processing Record 40 of Set 4 | mahanoro
# Processing Record 41 of Set 4 | karratha
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | marrakesh
# Processing Record 45 of Set 4 | milkovo
# Processing Record 46 of Set 4 | aripuana
# Processing Record 47 of Set 4 | saryagash
# Processing Record 48 of Set 4 | todos santos
# Processing Record 49 of Set 4 | novyy urengoy
# Processing Record 50 of Set 4 | chisinau
# Processing Record 1 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | udachnyy
# Processing Record 4 of Set 5 | grand-lahou
# Processing Record 5 of Set 5 | altea
# Processing Record 6 of Set 5 | pekan
# Processing Record 7 of Set 5 | kalomo
# City not found. Skipping...
# Processing Record 8 of Set 5 | natal
# Processing Record 9 of Set 5 | mayo
# Processing Record 10 of Set 5 | raja sansi
# Processing Record 11 of Set 5 | harper
# Processing Record 12 of Set 5 | isperih
# Processing Record 13 of Set 5 | sakata
# Processing Record 14 of Set 5 | tilichiki
# Processing Record 15 of Set 5 | astakos
# Processing Record 16 of Set 5 | arras
# Processing Record 17 of Set 5 | quelimane
# Processing Record 18 of Set 5 | ahipara
# Processing Record 19 of Set 5 | nalut
# Processing Record 20 of Set 5 | pompeia
# Processing Record 21 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 5 | srednekolymsk
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | mount gambier
# Processing Record 25 of Set 5 | tezze sul brenta
# Processing Record 26 of Set 5 | erzin
# Processing Record 27 of Set 5 | nong khae
# Processing Record 28 of Set 5 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 29 of Set 5 | panzhihua
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | sao miguel do araguaia
# Processing Record 32 of Set 5 | carauari
# Processing Record 33 of Set 5 | ketchikan
# Processing Record 34 of Set 5 | bridlington
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | colac
# Processing Record 37 of Set 5 | puerto madero
# Processing Record 38 of Set 5 | marawi
# Processing Record 39 of Set 5 | dovers
# Processing Record 40 of Set 5 | kalabo
# Processing Record 41 of Set 5 | iqaluit
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | viedma
# Processing Record 44 of Set 5 | ashland
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | palmer
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | bara
# Processing Record 2 of Set 6 | sibolga
# Processing Record 3 of Set 6 | arman
# Processing Record 4 of Set 6 | phan thiet
# Processing Record 5 of Set 6 | aksarka
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | morgan city
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | trondheim
# Processing Record 10 of Set 6 | chapleau
# Processing Record 11 of Set 6 | maceio
# Processing Record 12 of Set 6 | asfi
# Processing Record 13 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | uusikaupunki
# Processing Record 16 of Set 6 | tsnori
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | port hedland
# Processing Record 20 of Set 6 | paciran
# Processing Record 21 of Set 6 | evensk
# Processing Record 22 of Set 6 | raudeberg
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | husavik
# Processing Record 26 of Set 6 | tanda
# Processing Record 27 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 6 | plaster rock
# Processing Record 29 of Set 6 | kiunga
# Processing Record 30 of Set 6 | lake city
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 6 | gorontalo
# Processing Record 34 of Set 6 | greensburg
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | kingaroy
# Processing Record 37 of Set 6 | forio
# Processing Record 38 of Set 6 | skelleftea
# Processing Record 39 of Set 6 | ratnagiri
# Processing Record 40 of Set 6 | chapada dos guimaraes
# Processing Record 41 of Set 6 | varnavino
# Processing Record 42 of Set 6 | morag
# Processing Record 43 of Set 6 | talnakh
# Processing Record 44 of Set 6 | dragotesti
# Processing Record 45 of Set 6 | gushikawa
# Processing Record 46 of Set 6 | bundaberg
# Processing Record 47 of Set 6 | martapura
# Processing Record 48 of Set 6 | belyy yar
# Processing Record 49 of Set 6 | pevek
# Processing Record 50 of Set 6 | oranjestad
# Processing Record 1 of Set 7 | abu samrah
# Processing Record 2 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 7 | bardiyah
# Processing Record 4 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 7 | canto do buriti
# Processing Record 6 of Set 7 | puerto narino
# Processing Record 7 of Set 7 | medvezhyegorsk
# Processing Record 8 of Set 7 | whitehorse
# Processing Record 9 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 7 | ribnica
# Processing Record 11 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 7 | hobyo
# Processing Record 13 of Set 7 | paamiut
# Processing Record 14 of Set 7 | zeerust
# Processing Record 15 of Set 7 | zakamensk
# Processing Record 16 of Set 7 | inhambane
# Processing Record 17 of Set 7 | salinas
# Processing Record 18 of Set 7 | ust-uda
# Processing Record 19 of Set 7 | armidale
# Processing Record 20 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 7 | adrar
# Processing Record 22 of Set 7 | jardim
# Processing Record 23 of Set 7 | amahai
# Processing Record 24 of Set 7 | aklavik
# Processing Record 25 of Set 7 | teya
# Processing Record 26 of Set 7 | molina
# Processing Record 27 of Set 7 | oga
# Processing Record 28 of Set 7 | san rafael del sur
# Processing Record 29 of Set 7 | bandarbeyla
# Processing Record 30 of Set 7 | wasilla
# Processing Record 31 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 7 | pampierstad
# Processing Record 33 of Set 7 | kidal
# Processing Record 34 of Set 7 | laramie
# Processing Record 35 of Set 7 | komsomolskiy
# Processing Record 36 of Set 7 | suntar
# Processing Record 37 of Set 7 | cabedelo
# Processing Record 38 of Set 7 | san francisco
# Processing Record 39 of Set 7 | arinos
# Processing Record 40 of Set 7 | mount isa
# Processing Record 41 of Set 7 | heze
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | the valley
# Processing Record 44 of Set 7 | puerto colombia
# Processing Record 45 of Set 7 | ihiala
# Processing Record 46 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | atar
# Processing Record 49 of Set 7 | makat
# Processing Record 50 of Set 7 | pangkalanbuun
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | tabuk
# Processing Record 3 of Set 8 | mbuji-mayi
# Processing Record 4 of Set 8 | yining
# Processing Record 5 of Set 8 | samarai
# Processing Record 6 of Set 8 | pemangkat
# Processing Record 7 of Set 8 | xining
# Processing Record 8 of Set 8 | sigli
# Processing Record 9 of Set 8 | lorengau
# Processing Record 10 of Set 8 | mangai
# Processing Record 11 of Set 8 | masuguru
# Processing Record 12 of Set 8 | manggar
# Processing Record 13 of Set 8 | pinega
# Processing Record 14 of Set 8 | nyurba
# Processing Record 15 of Set 8 | namwala
# Processing Record 16 of Set 8 | gijon
# Processing Record 17 of Set 8 | ixtapa
# Processing Record 18 of Set 8 | sombrio
# Processing Record 19 of Set 8 | katangli
# Processing Record 20 of Set 8 | khatanga
# Processing Record 21 of Set 8 | grindavik
# Processing Record 22 of Set 8 | port-gentil
# Processing Record 23 of Set 8 | fort nelson
# Processing Record 24 of Set 8 | sur
# Processing Record 25 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 8 | port hardy
# Processing Record 27 of Set 8 | oussouye
# Processing Record 28 of Set 8 | gueugnon
# Processing Record 29 of Set 8 | san pedro
# Processing Record 30 of Set 8 | moose factory
# Processing Record 31 of Set 8 | svetlyy
# Processing Record 32 of Set 8 | sala
# Processing Record 33 of Set 8 | burica
# City not found. Skipping...
# Processing Record 34 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 8 | bambous virieux
# Processing Record 36 of Set 8 | kununurra
# Processing Record 37 of Set 8 | santo antonio do ica
# Processing Record 38 of Set 8 | garissa
# Processing Record 39 of Set 8 | wladyslawowo
# Processing Record 40 of Set 8 | birao
# Processing Record 41 of Set 8 | sucua
# Processing Record 42 of Set 8 | pechenga
# Processing Record 43 of Set 8 | krasnaya gora
# Processing Record 44 of Set 8 | champerico
# Processing Record 45 of Set 8 | dingle
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | mweka
# Processing Record 49 of Set 8 | aykhal
# Processing Record 50 of Set 8 | lebu
# Processing Record 1 of Set 9 | jalu
# Processing Record 2 of Set 9 | susehri
# Processing Record 3 of Set 9 | margate
# Processing Record 4 of Set 9 | guerrero negro
# Processing Record 5 of Set 9 | solnechnyy
# Processing Record 6 of Set 9 | yerbogachen
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | mehamn
# Processing Record 9 of Set 9 | taitung
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | asbe teferi
# Processing Record 12 of Set 9 | tautira
# Processing Record 13 of Set 9 | manavalakurichi
# Processing Record 14 of Set 9 | karpathos
# Processing Record 15 of Set 9 | sakaiminato
# Processing Record 16 of Set 9 | abeche
# Processing Record 17 of Set 9 | maraa
# Processing Record 18 of Set 9 | port macquarie
# Processing Record 19 of Set 9 | oranjemund
# Processing Record 20 of Set 9 | batagay
# Processing Record 21 of Set 9 | zatoka
# Processing Record 22 of Set 9 | port lincoln
# Processing Record 23 of Set 9 | aquiles serdan
# Processing Record 24 of Set 9 | caranavi
# Processing Record 25 of Set 9 | bathsheba
# Processing Record 26 of Set 9 | san cristobal
# Processing Record 27 of Set 9 | lardos
# Processing Record 28 of Set 9 | chippewa falls
# Processing Record 29 of Set 9 | poum
# Processing Record 30 of Set 9 | svetlogorsk
# Processing Record 31 of Set 9 | pacific grove
# Processing Record 32 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 9 | san quintin
# Processing Record 34 of Set 9 | krasnogorsk
# Processing Record 35 of Set 9 | garden city
# Processing Record 36 of Set 9 | santa rosa
# Processing Record 37 of Set 9 | opuwo
# Processing Record 38 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 39 of Set 9 | grand-santi
# Processing Record 40 of Set 9 | tam ky
# Processing Record 41 of Set 9 | hambantota
# Processing Record 42 of Set 9 | marietta
# Processing Record 43 of Set 9 | koumac
# Processing Record 44 of Set 9 | koslan
# Processing Record 45 of Set 9 | mikhaylovka
# Processing Record 46 of Set 9 | port blair
# Processing Record 47 of Set 9 | tongchuan
# Processing Record 48 of Set 9 | aktau
# Processing Record 49 of Set 9 | mendi
# Processing Record 50 of Set 9 | lakatoro
# Processing Record 1 of Set 10 | maragogi
# Processing Record 2 of Set 10 | spornoye
# Processing Record 3 of Set 10 | sept-iles
# Processing Record 4 of Set 10 | bethanien
# Processing Record 5 of Set 10 | byumba
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | chirilagua
# Processing Record 8 of Set 10 | nizwa
# Processing Record 9 of Set 10 | sao filipe
# Processing Record 10 of Set 10 | gdynia
# Processing Record 11 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 10 | vostok
# Processing Record 13 of Set 10 | hatillo
# Processing Record 14 of Set 10 | bari
# Processing Record 15 of Set 10 | dali
# Processing Record 16 of Set 10 | hervey bay
# Processing Record 17 of Set 10 | bud
# Processing Record 18 of Set 10 | mecca
# Processing Record 19 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 20 of Set 10 | oum hadjer
# Processing Record 21 of Set 10 | krasnoselkup
# Processing Record 22 of Set 10 | wattegama
# Processing Record 23 of Set 10 | oneonta
# Processing Record 24 of Set 10 | simga
# Processing Record 25 of Set 10 | bhander
# Processing Record 26 of Set 10 | mangrol
# Processing Record 27 of Set 10 | ahuimanu
# Processing Record 28 of Set 10 | vanavara
# Processing Record 29 of Set 10 | nanortalik
# Processing Record 30 of Set 10 | goderich
# Processing Record 31 of Set 10 | sao goncalo
# Processing Record 32 of Set 10 | trabzon
# Processing Record 33 of Set 10 | kruisfontein
# Processing Record 34 of Set 10 | smithers
# Processing Record 35 of Set 10 | sehithwa
# Processing Record 36 of Set 10 | galveston
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | constitucion
# Processing Record 39 of Set 10 | payson
# Processing Record 40 of Set 10 | terrace
# Processing Record 41 of Set 10 | norilsk
# Processing Record 42 of Set 10 | khani
# Processing Record 43 of Set 10 | sarkand
# Processing Record 44 of Set 10 | teluk nibung
# Processing Record 45 of Set 10 | ous
# Processing Record 46 of Set 10 | sioux lookout
# Processing Record 47 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 10 | mariental
# Processing Record 49 of Set 10 | davila
# Processing Record 50 of Set 10 | ayagoz
# Processing Record 1 of Set 11 | noumea
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | kendari
# Processing Record 4 of Set 11 | brae
# Processing Record 5 of Set 11 | lokosovo
# Processing Record 6 of Set 11 | saint-raymond
# Processing Record 7 of Set 11 | el vigia
# Processing Record 8 of Set 11 | mahibadhoo
# Processing Record 9 of Set 11 | saint-pierre
# Processing Record 10 of Set 11 | langfang
# Processing Record 11 of Set 11 | luanda
# Processing Record 12 of Set 11 | dawei
# Processing Record 13 of Set 11 | perth
# Processing Record 14 of Set 11 | shetpe
# Processing Record 15 of Set 11 | ossora
# Processing Record 16 of Set 11 | gat
# Processing Record 17 of Set 11 | usinsk
# Processing Record 18 of Set 11 | taltal
# Processing Record 19 of Set 11 | bajina basta
# Processing Record 20 of Set 11 | shache
# Processing Record 21 of Set 11 | salalah
# Processing Record 22 of Set 11 | pisco
# Processing Record 23 of Set 11 | emba
# Processing Record 24 of Set 11 | olavarria
# Processing Record 25 of Set 11 | pochutla
# Processing Record 26 of Set 11 | willowmore
# Processing Record 27 of Set 11 | bolshoy kamen
# Processing Record 28 of Set 11 | bajil
# Processing Record 29 of Set 11 | kushiro
# Processing Record 30 of Set 11 | dingli
# Processing Record 31 of Set 11 | bajram curri
# Processing Record 32 of Set 11 | pierre
# Processing Record 33 of Set 11 | utete
# Processing Record 34 of Set 11 | clinton
# Processing Record 35 of Set 11 | povenets
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | ternate
# Processing Record 38 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 11 | zheleznodorozhnyy
# Processing Record 40 of Set 11 | oskaloosa
# Processing Record 41 of Set 11 | santa maria
# Processing Record 42 of Set 11 | erenhot
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 11 | batemans bay
# Processing Record 46 of Set 11 | kibala
# Processing Record 47 of Set 11 | ust-ilimsk
# Processing Record 48 of Set 11 | misratah
# Processing Record 49 of Set 11 | hof
# Processing Record 50 of Set 11 | tsilna
# Processing Record 1 of Set 12 | morondava
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | agua branca
# Processing Record 4 of Set 12 | ovalle
# Processing Record 5 of Set 12 | sola
# Processing Record 6 of Set 12 | mehendiganj
# Processing Record 7 of Set 12 | grootfontein
# Processing Record 8 of Set 12 | ust-tsilma
# Processing Record 9 of Set 12 | sogdiondon
# City not found. Skipping...
# Processing Record 10 of Set 12 | derbent
# Processing Record 11 of Set 12 | matara
# Processing Record 12 of Set 12 | balsas
# Processing Record 13 of Set 12 | vanimo
# Processing Record 14 of Set 12 | savannah bight
# Processing Record 15 of Set 12 | kushima
# Processing Record 16 of Set 12 | pilibanga
# Processing Record 17 of Set 12 | aksha
# Processing Record 18 of Set 12 | ust-kuyga
# Processing Record 19 of Set 12 | florianopolis
# Processing Record 20 of Set 12 | sao raimundo das mangabeiras
# Processing Record 21 of Set 12 | chapais
# Processing Record 22 of Set 12 | kuminskiy
# Processing Record 23 of Set 12 | lusambo
# Processing Record 24 of Set 12 | mumford
# Processing Record 25 of Set 12 | kokomo
# Processing Record 26 of Set 12 | ostrovnoy
# Processing Record 27 of Set 12 | dudinka
# Processing Record 28 of Set 12 | johnstown
# Processing Record 29 of Set 12 | otacilio costa
# Processing Record 30 of Set 12 | prince rupert
# Processing Record 31 of Set 12 | narsaq
# Processing Record 32 of Set 12 | vila
# Processing Record 33 of Set 12 | jiuquan
# Processing Record 34 of Set 12 | nantucket
# Processing Record 35 of Set 12 | mukhen
# Processing Record 36 of Set 12 | urucara
# Processing Record 37 of Set 12 | patu
# Processing Record 38 of Set 12 | vestmannaeyjar
# Processing Record 39 of Set 12 | iracoubo
# Processing Record 40 of Set 12 | jutai
# Processing Record 41 of Set 12 | assiniboia
# Processing Record 42 of Set 12 | rundu
# Processing Record 43 of Set 12 | rio claro
# Processing Record 44 of Set 12 | asau
# Processing Record 45 of Set 12 | kainantu
# Processing Record 46 of Set 12 | kharan
# Processing Record 47 of Set 12 | moranbah
# Processing Record 48 of Set 12 | tchaourou
# Processing Record 49 of Set 12 | vila franca do campo
# Processing Record 50 of Set 12 | kyabe
# Processing Record 1 of Set 13 | krasnovishersk
# Processing Record 2 of Set 13 | russell
# Processing Record 3 of Set 13 | alta floresta
# Processing Record 4 of Set 13 | tupik
# Processing Record 5 of Set 13 | kamenka
# Processing Record 6 of Set 13 | ayr
# Processing Record 7 of Set 13 | bodden town
# Processing Record 8 of Set 13 | luwuk
# Processing Record 9 of Set 13 | chincha alta
# Processing Record 10 of Set 13 | tekeli
# Processing Record 11 of Set 13 | dargaville
# Processing Record 12 of Set 13 | bowmore
# Processing Record 13 of Set 13 | astana
# Processing Record 14 of Set 13 | waingapu
# Processing Record 15 of Set 13 | padang
# Processing Record 16 of Set 13 | plettenberg bay
# Processing Record 17 of Set 13 | pervomayskiy
# Processing Record 18 of Set 13 | fairbanks
# Processing Record 19 of Set 13 | mukhtolovo
# Processing Record 20 of Set 13 | yantal
# Processing Record 21 of Set 13 | den helder
# Processing Record 22 of Set 13 | auki
# Processing Record 23 of Set 13 | lasa
# Processing Record 24 of Set 13 | nakonde
# Processing Record 25 of Set 13 | yarada
# Processing Record 26 of Set 13 | la ronge
# Processing Record 27 of Set 13 | tubuala
# Processing Record 28 of Set 13 | buchanan
# Processing Record 29 of Set 13 | purepero
# Processing Record 30 of Set 13 | baiyin
# Processing Record 31 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 32 of Set 13 | beloha
# Processing Record 33 of Set 13 | benghazi
# Processing Record 34 of Set 13 | melo
# Processing Record 35 of Set 13 | dubbo
# Processing Record 36 of Set 13 | paka
# Processing Record 37 of Set 13 | ornskoldsvik
# Processing Record 38 of Set 13 | hofn
# Processing Record 39 of Set 13 | santander
# Processing Record 40 of Set 13 | katherine
# Processing Record 41 of Set 13 | phuket
# Processing Record 42 of Set 13 | saint-augustin
# Processing Record 43 of Set 13 | isla vista
# Processing Record 44 of Set 13 | igarka
# Processing Record 45 of Set 13 | acambay
# Processing Record 46 of Set 13 | nome
# Processing Record 47 of Set 13 | bavly
# Processing Record 48 of Set 13 | alice springs
# Processing Record 49 of Set 13 | yeppoon
# Processing Record 50 of Set 13 | muros
# Processing Record 1 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 14 | iranshahr
# Processing Record 3 of Set 14 | sahbuz
# Processing Record 4 of Set 14 | mwinilunga
# Processing Record 5 of Set 14 | caravelas
# Processing Record 6 of Set 14 | sovetskoye
# Processing Record 7 of Set 14 | elko
# Processing Record 8 of Set 14 | pleasant point
# Processing Record 9 of Set 14 | chicama
# Processing Record 10 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 11 of Set 14 | kaka
# Processing Record 12 of Set 14 | millet
# Processing Record 13 of Set 14 | olafsvik
# Processing Record 14 of Set 14 | cubara
# Processing Record 15 of Set 14 | mushie
# Processing Record 16 of Set 14 | kasongo
# Processing Record 17 of Set 14 | volovo
# Processing Record 18 of Set 14 | rockport
# Processing Record 19 of Set 14 | praya
# Processing Record 20 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 14 | williamsport
# Processing Record 22 of Set 14 | serebryansk
# Processing Record 23 of Set 14 | tarko-sale
# Processing Record 24 of Set 14 | angola
# Processing Record 25 of Set 14 | cabo san lucas
# Processing Record 26 of Set 14 | sinop
# Processing Record 27 of Set 14 | araouane
# Processing Record 28 of Set 14 | kruszwica
# Processing Record 29 of Set 14 | kalmunai
# Processing Record 30 of Set 14 | taboao da serra
# Processing Record 31 of Set 14 | banjar
# Processing Record 32 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 14 | pasadena
# Processing Record 34 of Set 14 | mogadishu
# Processing Record 35 of Set 14 | kautokeino
# Processing Record 36 of Set 14 | roald
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 14 | trincomalee
# Processing Record 41 of Set 14 | walvis bay
# Processing Record 42 of Set 14 | doha
# Processing Record 43 of Set 14 | koubia
# Processing Record 44 of Set 14 | cayenne
# Processing Record 45 of Set 14 | chilca
# Processing Record 46 of Set 14 | longyearbyen
# Processing Record 47 of Set 14 | ercis
# Processing Record 48 of Set 14 | olinda
# Processing Record 49 of Set 14 | praia
# Processing Record 50 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 15 | aden
# Processing Record 3 of Set 15 | marondera
# Processing Record 4 of Set 15 | iskateley
# Processing Record 5 of Set 15 | selma
# Processing Record 6 of Set 15 | kahului
# Processing Record 7 of Set 15 | nhulunbuy
# Processing Record 8 of Set 15 | loanda
# Processing Record 9 of Set 15 | motygino
# Processing Record 10 of Set 15 | gumushane
# City not found. Skipping...
# Processing Record 11 of Set 15 | collie
# Processing Record 12 of Set 15 | storforshei
# Processing Record 13 of Set 15 | port moresby
# Processing Record 14 of Set 15 | dongsheng
# Processing Record 15 of Set 15 | diffa
# Processing Record 16 of Set 15 | marsberg
# Processing Record 17 of Set 15 | mizpe ramon
# City not found. Skipping...
# Processing Record 18 of Set 15 | alekseyevsk
# Processing Record 19 of Set 15 | arawa
# Processing Record 20 of Set 15 | hovd
# Processing Record 21 of Set 15 | moindou
# Processing Record 22 of Set 15 | preobrazheniye
# Processing Record 23 of Set 15 | tuckahoe
# Processing Record 24 of Set 15 | joshimath
# Processing Record 25 of Set 15 | nhamunda
# Processing Record 26 of Set 15 | brewster
# Processing Record 27 of Set 15 | cortez
# Processing Record 28 of Set 15 | fereydunshahr
# Processing Record 29 of Set 15 | soto la marina
# Processing Record 30 of Set 15 | vuktyl
# Processing Record 31 of Set 15 | lampang
# Processing Record 32 of Set 15 | bissora
# Processing Record 33 of Set 15 | anloga
# Processing Record 34 of Set 15 | thinadhoo
# Processing Record 35 of Set 15 | farafangana
# Processing Record 36 of Set 15 | dalvik
# Processing Record 37 of Set 15 | bondo
# Processing Record 38 of Set 15 | half moon bay
# Processing Record 39 of Set 15 | sar-e pul
# Processing Record 40 of Set 15 | balkhash
# Processing Record 41 of Set 15 | ugoofaaru
# Processing Record 42 of Set 15 | muisne
# Processing Record 43 of Set 15 | sakhnovshchyna
# Processing Record 44 of Set 15 | peyima
# Processing Record 45 of Set 15 | strezhevoy
# Processing Record 46 of Set 15 | obzor
# Processing Record 47 of Set 15 | amurzet
# Processing Record 48 of Set 15 | kuito
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tiksi  71.6872  128.8694    -25.56        86         100
# 1     Sinnamary   5.3833  -52.9500     79.52        85          91
# 2      Qaqortoq  60.7167  -46.0333     33.80        25           1
# 3      Saldanha -33.0117   17.9442     73.40        68          20
# 4        Chahal  15.7500  -89.5667     91.81        36           8
# 5     Busselton -33.6500  115.3333     59.00        95         100
# 6        Barrow  71.2906 -156.7887     -0.40        71          90
# 7      Antalaha -14.9003   50.2788     77.86        78          63
# 8       Rikitea -23.1203 -134.9692     77.65        74         100
# 9  Punta Arenas -53.1500  -70.9167     59.00        41          40
#
#    Wind Speed Country                 Date Weather Description
# 0        5.82      RU  2021-02-06 18:05:26     overcast clouds
# 1       16.06      GF  2021-02-06 18:05:26     overcast clouds
# 2       24.16      GL  2021-02-06 18:05:26           clear sky
# 3       18.41      ZA  2021-02-06 18:05:26          few clouds
# 4        0.60      GT  2021-02-06 18:05:26           clear sky
# 5        1.01      AU  2021-02-06 18:05:26          light rain
# 6       11.50      US  2021-02-06 18:01:08                haze
# 7        1.23      MG  2021-02-06 18:05:27       broken clouds
# 8       12.37      PF  2021-02-06 18:05:27     overcast clouds
# 9       21.85      CL  2021-02-06 18:05:27    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
